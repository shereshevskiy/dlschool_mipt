# %%
import pandas as pd
import numpy as np

# %%
submission=pd.read_csv('submission.csv')

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
test.head()
# Out:
#    ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 0            42            56.10    2386.85    Male                0
# 1            29            98.50    3004.15    Male                1
# 2             9            76.25     684.85    Male                0
# 3            67            74.00     4868.4  Female                0
# 4            71            20.10     1389.6  Female                0
#
#   HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 0        Yes       No             Yes                     Yes
# 1        Yes       No             Yes                     Yes
# 2         No       No             Yes                     Yes
# 3        Yes      Yes             Yes                     Yes
# 4        Yes      Yes             Yes                      No
#
#   HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 0                DSL                      Yes                   No
# 1        Fiber optic                       No                   No
# 2        Fiber optic                       No                   No
# 3                DSL                      Yes                  Yes
# 4                 No      No internet service  No internet service
#
#    HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 0                   No                   No                   No
# 1                  Yes                   No                  Yes
# 2                   No                   No                   No
# 3                   No                  Yes                  Yes
# 4  No internet service  No internet service  No internet service
#
#   HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 0                   No         One year                 No
# 1                  Yes   Month-to-month                Yes
# 2                   No   Month-to-month                Yes
# 3                   No         Two year                 No
# 4  No internet service         Two year                 No
#
#                PaymentMethod
# 0    Credit card (automatic)
# 1           Electronic check
# 2           Electronic check
# 3    Credit card (automatic)
# 4  Bank transfer (automatic)

# %%
for i in list(train):
    print(train[i].value_counts())
# Out:
# 1     457
# 72    284
# 2     165
# 3     162
# 4     136
#      ...
# 57     39
# 39     35
# 36     34
# 44     34
# 0       9
# Name: ClientPeriod, Length: 73, dtype: int64
# 20.05     46
# 19.65     35
# 19.95     34
# 20.00     33
# 19.80     32
#           ..
# 51.60      1
# 52.30      1
# 114.75     1
# 58.70      1
# 39.20      1
# Name: MonthlySpending, Length: 1468, dtype: int64
#            9
# 20.2       9
# 19.75      8
# 20.05      6
# 19.65      6
#           ..
# 2354.8     1
# 784.45     1
# 7690.9     1
# 2448.75    1
# 8424.9     1
# Name: TotalSpent, Length: 4978, dtype: int64
# Male      2655
# Female    2627
# Name: Sex, dtype: int64
# 0    4440
# 1     842
# Name: IsSeniorCitizen, dtype: int64
# No     2705
# Yes    2577
# Name: HasPartner, dtype: int64
# No     3676
# Yes    1606
# Name: HasChild, dtype: int64
# Yes    4761
# No      521
# Name: HasPhoneService, dtype: int64
# No                  2511
# Yes                 2250
# No phone service     521
# Name: HasMultiplePhoneNumbers, dtype: int64
# Fiber optic    2341
# DSL            1800
# No             1141
# Name: HasInternetService, dtype: int64
# No                     2612
# Yes                    1529
# No internet service    1141
# Name: HasOnlineSecurityService, dtype: int64
# No                     2332
# Yes                    1809
# No internet service    1141
# Name: HasOnlineBackup, dtype: int64
# No                     2317
# Yes                    1824
# No internet service    1141
# Name: HasDeviceProtection, dtype: int64
# No                     2604
# Yes                    1537
# No internet service    1141
# Name: HasTechSupportAccess, dtype: int64
# No                     2099
# Yes                    2042
# No internet service    1141
# Name: HasOnlineTV, dtype: int64
# No                     2081
# Yes                    2060
# No internet service    1141
# Name: HasMovieSubscription, dtype: int64
# Month-to-month    2920
# Two year          1280
# One year          1082
# Name: HasContractPhone, dtype: int64
# Yes    3148
# No     2134
# Name: IsBillingPaperless, dtype: int64
# Electronic check             1786
# Mailed check                 1194
# Bank transfer (automatic)    1159
# Credit card (automatic)      1143
# Name: PaymentMethod, dtype: int64
# 0    3898
# 1    1384
# Name: Churn, dtype: int64

# %%
import xgboost

# %%
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
from matplotlib import pyplot

# %%
Xtrain=train.drop(['Churn'],1)
Xtrain['is_test'] = False
test['is_test'] = True
X = pd.concat([Xtrain, test], axis=0)
X.index = range(len(X))
X.columns = X.columns.str.lower()

# %%
y=train.Churn

# %%
X.head()
# Out:
#    clientperiod  monthlyspending totalspent     sex  isseniorcitizen  \
# 0            55            19.50    1026.35    Male                0
# 1            72            25.85     1872.2    Male                0
# 2             1            75.90       75.9    Male                0
# 3            32            79.30       2570  Female                1
# 4            60           115.25    6758.45  Female                0
#
#   haspartner haschild hasphoneservice hasmultiplephonenumbers  \
# 0        Yes      Yes             Yes                      No
# 1        Yes       No             Yes                     Yes
# 2         No       No             Yes                      No
# 3        Yes       No             Yes                     Yes
# 4        Yes      Yes             Yes                     Yes
#
#   hasinternetservice hasonlinesecurityservice      hasonlinebackup  \
# 0                 No      No internet service  No internet service
# 1                 No      No internet service  No internet service
# 2        Fiber optic                       No                   No
# 3        Fiber optic                       No                   No
# 4        Fiber optic                      Yes                  Yes
#
#    hasdeviceprotection hastechsupportaccess          hasonlinetv  \
# 0  No internet service  No internet service  No internet service
# 1  No internet service  No internet service  No internet service
# 2                   No                  Yes                   No
# 3                  Yes                   No                   No
# 4                  Yes                  Yes                  Yes
#
#   hasmoviesubscription hascontractphone isbillingpaperless  \
# 0  No internet service         One year                 No
# 1  No internet service         Two year                 No
# 2                   No   Month-to-month                Yes
# 3                   No   Month-to-month                 No
# 4                  Yes         Two year                 No
#
#              paymentmethod  is_test
# 0             Mailed check    False
# 1  Credit card (automatic)    False
# 2         Electronic check    False
# 3             Mailed check    False
# 4  Credit card (automatic)    False

# %%
X.totalspent= pd.to_numeric(X.totalspent, errors='coerce')

# %%
list(X)
# Out:
# ['clientperiod',
#  'monthlyspending',
#  'totalspent',
#  'sex',
#  'isseniorcitizen',
#  'haspartner',
#  'haschild',
#  'hasphoneservice',
#  'hasmultiplephonenumbers',
#  'hasinternetservice',
#  'hasonlinesecurityservice',
#  'hasonlinebackup',
#  'hasdeviceprotection',
#  'hastechsupportaccess',
#  'hasonlinetv',
#  'hasmoviesubscription',
#  'hascontractphone',
#  'isbillingpaperless',
#  'paymentmethod',
#  'is_test']

# %%
df_dummies = pd.get_dummies(X, columns=['sex', 'isseniorcitizen','haspartner','haschild','hasphoneservice',
 'hasmultiplephonenumbers',
 'hasinternetservice',
 'hasonlinesecurityservice',
 'hasonlinebackup',
 'hasdeviceprotection',
 'hastechsupportaccess',
 'hasonlinetv',
 'hasmoviesubscription',
 'hascontractphone',
 'isbillingpaperless',
 'paymentmethod'])

# %%
list(df_dummies)
# Out:
# ['clientperiod',
#  'monthlyspending',
#  'totalspent',
#  'is_test',
#  'sex_Female',
#  'sex_Male',
#  'isseniorcitizen_0',
#  'isseniorcitizen_1',
#  'haspartner_No',
#  'haspartner_Yes',
#  'haschild_No',
#  'haschild_Yes',
#  'hasphoneservice_No',
#  'hasphoneservice_Yes',
#  'hasmultiplephonenumbers_No',
#  'hasmultiplephonenumbers_No phone service',
#  'hasmultiplephonenumbers_Yes',
#  'hasinternetservice_DSL',
#  'hasinternetservice_Fiber optic',
#  'hasinternetservice_No',
#  'hasonlinesecurityservice_No',
#  'hasonlinesecurityservice_No internet service',
#  'hasonlinesecurityservice_Yes',
#  'hasonlinebackup_No',
#  'hasonlinebackup_No internet service',
#  'hasonlinebackup_Yes',
#  'hasdeviceprotection_No',
#  'hasdeviceprotection_No internet service',
#  'hasdeviceprotection_Yes',
#  'hastechsupportaccess_No',
#  'hastechsupportaccess_No internet service',
#  'hastechsupportaccess_Yes',
#  'hasonlinetv_No',
#  'hasonlinetv_No internet service',
#  'hasonlinetv_Yes',
#  'hasmoviesubscription_No',
#  'hasmoviesubscription_No internet service',
#  'hasmoviesubscription_Yes',
#  'hascontractphone_Month-to-month',
#  'hascontractphone_One year',
#  'hascontractphone_Two year',
#  'isbillingpaperless_No',
#  'isbillingpaperless_Yes',
#  'paymentmethod_Bank transfer (automatic)',
#  'paymentmethod_Credit card (automatic)',
#  'paymentmethod_Electronic check',
#  'paymentmethod_Mailed check']

# %%
df_dummies.drop(["sex_Female", "isseniorcitizen_0", "haschild_No", "haschild_No", "hasphoneservice_No",'isbillingpaperless_No'], axis=1, inplace=True)

# %%
df_dummies.head()
# Out:
#    clientperiod  monthlyspending  totalspent  is_test  sex_Male  \
# 0            55            19.50     1026.35    False         1
# 1            72            25.85     1872.20    False         1
# 2             1            75.90       75.90    False         1
# 3            32            79.30     2570.00    False         0
# 4            60           115.25     6758.45    False         0
#
#    isseniorcitizen_1  haspartner_No  haspartner_Yes  haschild_Yes  \
# 0                  0              0               1             1
# 1                  0              0               1             0
# 2                  0              1               0             0
# 3                  1              0               1             0
# 4                  0              0               1             1
#
#    hasphoneservice_Yes  ...  hasmoviesubscription_No internet service  \
# 0                    1  ...                                         1
# 1                    1  ...                                         1
# 2                    1  ...                                         0
# 3                    1  ...                                         0
# 4                    1  ...                                         0
#
#    hasmoviesubscription_Yes  hascontractphone_Month-to-month  \
# 0                         0                                0
# 1                         0                                0
# 2                         0                                1
# 3                         0                                1
# 4                         1                                0
#
#    hascontractphone_One year  hascontractphone_Two year  \
# 0                          1                          0
# 1                          0                          1
# 2                          0                          0
# 3                          0                          0
# 4                          0                          1
#
#    isbillingpaperless_Yes  paymentmethod_Bank transfer (automatic)  \
# 0                       0                                        0
# 1                       0                                        0
# 2                       1                                        0
# 3                       0                                        0
# 4                       0                                        0
#
#    paymentmethod_Credit card (automatic)  paymentmethod_Electronic check  \
# 0                                      0                               0
# 1                                      1                               0
# 2                                      0                               1
# 3                                      0                               0
# 4                                      1                               0
#
#    paymentmethod_Mailed check
# 0                           1
# 1                           0
# 2                           0
# 3                           1
# 4                           0
#
# [5 rows x 42 columns]

# %%
Xtrain = df_dummies[df_dummies.is_test==0].drop('is_test', axis=1)
Xtest = df_dummies[df_dummies.is_test==1].drop('is_test', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xtrain, y, test_size=0.33, random_state=42)

# %%
model = XGBClassifier()
n_estimators = range(10, 100, 10)
param_grid = dict(n_estimators=n_estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(model, param_grid, scoring="roc_auc", n_jobs=-1, cv=kfold)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.850308 using {'n_estimators': 70}

# %%
params = {'n_estimators': 50,
          'learning_rate': 0.03,
          'max_depth': 5,
          'min_child_weight': 1,
          'subsample': 0.8,
          'colsample_bytree': 0.8,
          'n_jobs': -1}
clf_xgb = XGBClassifier(**params)

clf_xgb.fit(X_train, y_train, eval_metric='auc', eval_set=[[X_train, y_train], [X_test, y_test]])

best_params = params
# Out:
# [0]	validation_0-auc:0.854993	validation_1-auc:0.812725
# [1]	validation_0-auc:0.861573	validation_1-auc:0.815777
# [2]	validation_0-auc:0.86484	validation_1-auc:0.819359
# [3]	validation_0-auc:0.866373	validation_1-auc:0.822718
# [4]	validation_0-auc:0.869581	validation_1-auc:0.825339
# [5]	validation_0-auc:0.870795	validation_1-auc:0.82753
# [6]	validation_0-auc:0.871326	validation_1-auc:0.82949
# [7]	validation_0-auc:0.872074	validation_1-auc:0.82927
# [8]	validation_0-auc:0.872333	validation_1-auc:0.829477
# [9]	validation_0-auc:0.873101	validation_1-auc:0.829931
# [10]	validation_0-auc:0.873626	validation_1-auc:0.829757
# [11]	validation_0-auc:0.873872	validation_1-auc:0.830292
# [12]	validation_0-auc:0.875009	validation_1-auc:0.83141
# [13]	validation_0-auc:0.875741	validation_1-auc:0.831406
# [14]	validation_0-auc:0.876141	validation_1-auc:0.831303
# [15]	validation_0-auc:0.876264	validation_1-auc:0.831815
# [16]	validation_0-auc:0.876488	validation_1-auc:0.832203
# [17]	validation_0-auc:0.87734	validation_1-auc:0.832077
# [18]	validation_0-auc:0.8777	validation_1-auc:0.831895
# [19]	validation_0-auc:0.87776	validation_1-auc:0.831972
# [20]	validation_0-auc:0.878336	validation_1-auc:0.831279
# [21]	validation_0-auc:0.878783	validation_1-auc:0.831083
# [22]	validation_0-auc:0.879207	validation_1-auc:0.831235
# [23]	validation_0-auc:0.87966	validation_1-auc:0.831403
# [24]	validation_0-auc:0.880149	validation_1-auc:0.831848
# [25]	validation_0-auc:0.88034	validation_1-auc:0.831353
# [26]	validation_0-auc:0.880852	validation_1-auc:0.831192
# [27]	validation_0-auc:0.881302	validation_1-auc:0.831722
# [28]	validation_0-auc:0.881554	validation_1-auc:0.831963
# [29]	validation_0-auc:0.882338	validation_1-auc:0.83169
# [30]	validation_0-auc:0.882837	validation_1-auc:0.831764
# [31]	validation_0-auc:0.883166	validation_1-auc:0.831519
# [32]	validation_0-auc:0.883592	validation_1-auc:0.831277
# [33]	validation_0-auc:0.883693	validation_1-auc:0.831527
# [34]	validation_0-auc:0.88407	validation_1-auc:0.831635
# [35]	validation_0-auc:0.884455	validation_1-auc:0.83139
# [36]	validation_0-auc:0.884558	validation_1-auc:0.831367
# [37]	validation_0-auc:0.884683	validation_1-auc:0.83165
# [38]	validation_0-auc:0.884966	validation_1-auc:0.83208
# [39]	validation_0-auc:0.885739	validation_1-auc:0.83251
# [40]	validation_0-auc:0.885946	validation_1-auc:0.832069
# [41]	validation_0-auc:0.886589	validation_1-auc:0.831787
# [42]	validation_0-auc:0.886804	validation_1-auc:0.832071
# [43]	validation_0-auc:0.886983	validation_1-auc:0.832159
# [44]	validation_0-auc:0.887067	validation_1-auc:0.832037
# [45]	validation_0-auc:0.887297	validation_1-auc:0.832045
# [46]	validation_0-auc:0.887846	validation_1-auc:0.832134
# [47]	validation_0-auc:0.888118	validation_1-auc:0.832139
# [48]	validation_0-auc:0.888411	validation_1-auc:0.832111
# [49]	validation_0-auc:0.888647	validation_1-auc:0.832063

# %%
def find_params(clf, param_grid):
    clf = GridSearchCV(clf, param_grid, scoring='roc_auc', cv=[(np.arange(len(X_train)),
                                                               np.arange(len(X_test)) + len(X_train))],
                  verbose=3)

    clf.fit(pd.concat([X_train, X_test]).values, pd.concat([y_train, y_test]).values)
    best_params = clf.best_estimator_.get_params()
    print('Best test ROC AUC: ', clf.best_score_)
    print('Best params: ', best_params)
    return best_params

# %%
from sklearn.model_selection import GridSearchCV

clf_xgb = XGBClassifier(**best_params)

param_grid = {
    'max_depth': [3,4, 5,6,7,8,9, 10],
    'min_child_weight': [5,10,15, 20, 50]#[1, 5, 10]
}

best_params = find_params(clf_xgb, param_grid)
# Out:
# Fitting 1 folds for each of 40 candidates, totalling 40 fits
# [CV] max_depth=3, min_child_weight=5 .................................
# [CV] ..... max_depth=3, min_child_weight=5, score=0.830, total=   0.2s
# [CV] max_depth=3, min_child_weight=10 ................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] .... max_depth=3, min_child_weight=10, score=0.830, total=   0.2s
# [CV] max_depth=3, min_child_weight=15 ................................
# [CV] .... max_depth=3, min_child_weight=15, score=0.830, total=   0.2s
# [CV] max_depth=3, min_child_weight=20 ................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] .... max_depth=3, min_child_weight=20, score=0.830, total=   0.2s
# [CV] max_depth=3, min_child_weight=100 ...............................
# [CV] ... max_depth=3, min_child_weight=100, score=0.823, total=   0.1s
# [CV] max_depth=4, min_child_weight=5 .................................
# [CV] ..... max_depth=4, min_child_weight=5, score=0.833, total=   0.2s
# [CV] max_depth=4, min_child_weight=10 ................................
# [CV] .... max_depth=4, min_child_weight=10, score=0.833, total=   0.2s
# [CV] max_depth=4, min_child_weight=15 ................................
# [CV] .... max_depth=4, min_child_weight=15, score=0.833, total=   0.2s
# [CV] max_depth=4, min_child_weight=20 ................................
# [CV] .... max_depth=4, min_child_weight=20, score=0.832, total=   0.2s
# [CV] max_depth=4, min_child_weight=100 ...............................
# [CV] ... max_depth=4, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=5, min_child_weight=5 .................................
# [CV] ..... max_depth=5, min_child_weight=5, score=0.833, total=   0.2s
# [CV] max_depth=5, min_child_weight=10 ................................
# [CV] .... max_depth=5, min_child_weight=10, score=0.833, total=   0.2s
# [CV] max_depth=5, min_child_weight=15 ................................
# [CV] .... max_depth=5, min_child_weight=15, score=0.833, total=   0.2s
# [CV] max_depth=5, min_child_weight=20 ................................
# [CV] .... max_depth=5, min_child_weight=20, score=0.833, total=   0.2s
# [CV] max_depth=5, min_child_weight=100 ...............................
# [CV] ... max_depth=5, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=6, min_child_weight=5 .................................
# [CV] ..... max_depth=6, min_child_weight=5, score=0.831, total=   0.3s
# [CV] max_depth=6, min_child_weight=10 ................................
# [CV] .... max_depth=6, min_child_weight=10, score=0.831, total=   0.3s
# [CV] max_depth=6, min_child_weight=15 ................................
# [CV] .... max_depth=6, min_child_weight=15, score=0.833, total=   0.3s
# [CV] max_depth=6, min_child_weight=20 ................................
# [CV] .... max_depth=6, min_child_weight=20, score=0.833, total=   0.3s
# [CV] max_depth=6, min_child_weight=100 ...............................
# [CV] ... max_depth=6, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=7, min_child_weight=5 .................................
# [CV] ..... max_depth=7, min_child_weight=5, score=0.830, total=   0.3s
# [CV] max_depth=7, min_child_weight=10 ................................
# [CV] .... max_depth=7, min_child_weight=10, score=0.831, total=   0.3s
# [CV] max_depth=7, min_child_weight=15 ................................
# [CV] .... max_depth=7, min_child_weight=15, score=0.833, total=   0.3s
# [CV] max_depth=7, min_child_weight=20 ................................
# [CV] .... max_depth=7, min_child_weight=20, score=0.833, total=   0.3s
# [CV] max_depth=7, min_child_weight=100 ...............................
# [CV] ... max_depth=7, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=8, min_child_weight=5 .................................
# [CV] ..... max_depth=8, min_child_weight=5, score=0.828, total=   0.4s
# [CV] max_depth=8, min_child_weight=10 ................................
# [CV] .... max_depth=8, min_child_weight=10, score=0.830, total=   0.3s
# [CV] max_depth=8, min_child_weight=15 ................................
# [CV] .... max_depth=8, min_child_weight=15, score=0.833, total=   0.3s
# [CV] max_depth=8, min_child_weight=20 ................................
# [CV] .... max_depth=8, min_child_weight=20, score=0.833, total=   0.3s
# [CV] max_depth=8, min_child_weight=100 ...............................
# [CV] ... max_depth=8, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=9, min_child_weight=5 .................................
# [CV] ..... max_depth=9, min_child_weight=5, score=0.827, total=   0.4s
# [CV] max_depth=9, min_child_weight=10 ................................
# [CV] .... max_depth=9, min_child_weight=10, score=0.830, total=   0.3s
# [CV] max_depth=9, min_child_weight=15 ................................
# [CV] .... max_depth=9, min_child_weight=15, score=0.833, total=   0.3s
# [CV] max_depth=9, min_child_weight=20 ................................
# [CV] .... max_depth=9, min_child_weight=20, score=0.833, total=   0.3s
# [CV] max_depth=9, min_child_weight=100 ...............................
# [CV] ... max_depth=9, min_child_weight=100, score=0.823, total=   0.2s
# [CV] max_depth=10, min_child_weight=5 ................................
# [CV] .... max_depth=10, min_child_weight=5, score=0.827, total=   0.4s
# [CV] max_depth=10, min_child_weight=10 ...............................
# [CV] ... max_depth=10, min_child_weight=10, score=0.830, total=   0.4s
# [CV] max_depth=10, min_child_weight=15 ...............................
# [CV] ... max_depth=10, min_child_weight=15, score=0.833, total=   0.3s
# [CV] max_depth=10, min_child_weight=20 ...............................
# [CV] ... max_depth=10, min_child_weight=20, score=0.833, total=   0.3s
# [CV] max_depth=10, min_child_weight=100 ..............................
# [CV] .. max_depth=10, min_child_weight=100, score=0.823, total=   0.2s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   10.0s finished
# Best test ROC AUC:  0.8334356010544939
# Best params:  {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.03, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 15, 'missing': None, 'n_estimators': 50, 'n_jobs': -1, 'nthread': None, 'objective': 'binary:logistic', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': None, 'silent': None, 'subsample': 0.8, 'verbosity': 1}

# %%
clf_xgb = XGBClassifier(**best_params)

param_grid = {
    'gamma': np.linspace(0, 0.5, 5)
}

best_params = find_params(clf_xgb, param_grid)
# Out:
# Fitting 1 folds for each of 5 candidates, totalling 5 fits
# [CV] gamma=0.0 .......................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........................... gamma=0.0, score=0.833, total=   0.2s
# [CV] gamma=0.125 .....................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] ......................... gamma=0.125, score=0.834, total=   0.3s
# [CV] gamma=0.25 ......................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] .......................... gamma=0.25, score=0.833, total=   0.2s
# [CV] gamma=0.375 .....................................................
# [CV] ......................... gamma=0.375, score=0.834, total=   0.2s
# [CV] gamma=0.5 .......................................................
# [CV] ........................... gamma=0.5, score=0.834, total=   0.2s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.1s finished
# Best test ROC AUC:  0.8337957232862727
# Best params:  {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.03, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 15, 'missing': None, 'n_estimators': 50, 'n_jobs': -1, 'nthread': None, 'objective': 'binary:logistic', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': None, 'silent': None, 'subsample': 0.8, 'verbosity': 1}

# %%
clf_xgb = XGBClassifier(**best_params)

param_grid = {
    'subsample': np.linspace(0.5, 1, 6),
    'colsample_bytree': np.linspace(0.5, 1, 6)
}

best_params = find_params(clf_xgb, param_grid)
# Out:
# Fitting 1 folds for each of 36 candidates, totalling 36 fits
# [CV] colsample_bytree=0.5, subsample=0.5 .............................
# [CV] . colsample_bytree=0.5, subsample=0.5, score=0.835, total=   0.2s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] colsample_bytree=0.5, subsample=0.6 .............................
# [CV] . colsample_bytree=0.5, subsample=0.6, score=0.835, total=   0.2s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] colsample_bytree=0.5, subsample=0.7 .............................
# [CV] . colsample_bytree=0.5, subsample=0.7, score=0.835, total=   0.2s
# [CV] colsample_bytree=0.5, subsample=0.8 .............................
# [CV] . colsample_bytree=0.5, subsample=0.8, score=0.835, total=   0.2s
# [CV] colsample_bytree=0.5, subsample=0.9 .............................
# [CV] . colsample_bytree=0.5, subsample=0.9, score=0.835, total=   0.2s
# [CV] colsample_bytree=0.5, subsample=1.0 .............................
# [CV] . colsample_bytree=0.5, subsample=1.0, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=0.5 .............................
# [CV] . colsample_bytree=0.6, subsample=0.5, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=0.6 .............................
# [CV] . colsample_bytree=0.6, subsample=0.6, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=0.7 .............................
# [CV] . colsample_bytree=0.6, subsample=0.7, score=0.835, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=0.8 .............................
# [CV] . colsample_bytree=0.6, subsample=0.8, score=0.835, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=0.9 .............................
# [CV] . colsample_bytree=0.6, subsample=0.9, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.6, subsample=1.0 .............................
# [CV] . colsample_bytree=0.6, subsample=1.0, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=0.5 .............................
# [CV] . colsample_bytree=0.7, subsample=0.5, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=0.6 .............................
# [CV] . colsample_bytree=0.7, subsample=0.6, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=0.7 .............................
# [CV] . colsample_bytree=0.7, subsample=0.7, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=0.8 .............................
# [CV] . colsample_bytree=0.7, subsample=0.8, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=0.9 .............................
# [CV] . colsample_bytree=0.7, subsample=0.9, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.7, subsample=1.0 .............................
# [CV] . colsample_bytree=0.7, subsample=1.0, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.8, subsample=0.5 .............................
# [CV] . colsample_bytree=0.8, subsample=0.5, score=0.833, total=   0.3s
# [CV] colsample_bytree=0.8, subsample=0.6 .............................
# [CV] . colsample_bytree=0.8, subsample=0.6, score=0.833, total=   0.3s
# [CV] colsample_bytree=0.8, subsample=0.7 .............................
# [CV] . colsample_bytree=0.8, subsample=0.7, score=0.834, total=   0.3s
# [CV] colsample_bytree=0.8, subsample=0.8 .............................
# [CV] . colsample_bytree=0.8, subsample=0.8, score=0.834, total=   0.2s
# [CV] colsample_bytree=0.8, subsample=0.9 .............................
# [CV] . colsample_bytree=0.8, subsample=0.9, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.8, subsample=1.0 .............................
# [CV] . colsample_bytree=0.8, subsample=1.0, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.9, subsample=0.5 .............................
# [CV] . colsample_bytree=0.9, subsample=0.5, score=0.832, total=   0.3s
# [CV] colsample_bytree=0.9, subsample=0.6 .............................
# [CV] . colsample_bytree=0.9, subsample=0.6, score=0.832, total=   0.3s
# [CV] colsample_bytree=0.9, subsample=0.7 .............................
# [CV] . colsample_bytree=0.9, subsample=0.7, score=0.834, total=   0.3s
# [CV] colsample_bytree=0.9, subsample=0.8 .............................
# [CV] . colsample_bytree=0.9, subsample=0.8, score=0.834, total=   0.3s
# [CV] colsample_bytree=0.9, subsample=0.9 .............................
# [CV] . colsample_bytree=0.9, subsample=0.9, score=0.833, total=   0.2s
# [CV] colsample_bytree=0.9, subsample=1.0 .............................
# [CV] . colsample_bytree=0.9, subsample=1.0, score=0.833, total=   0.2s
# [CV] colsample_bytree=1.0, subsample=0.5 .............................
# [CV] . colsample_bytree=1.0, subsample=0.5, score=0.833, total=   0.3s
# [CV] colsample_bytree=1.0, subsample=0.6 .............................
# [CV] . colsample_bytree=1.0, subsample=0.6, score=0.833, total=   0.3s
# [CV] colsample_bytree=1.0, subsample=0.7 .............................
# [CV] . colsample_bytree=1.0, subsample=0.7, score=0.834, total=   0.3s
# [CV] colsample_bytree=1.0, subsample=0.8 .............................
# [CV] . colsample_bytree=1.0, subsample=0.8, score=0.833, total=   0.3s
# [CV] colsample_bytree=1.0, subsample=0.9 .............................
# [CV] . colsample_bytree=1.0, subsample=0.9, score=0.832, total=   0.3s
# [CV] colsample_bytree=1.0, subsample=1.0 .............................
# [CV] . colsample_bytree=1.0, subsample=1.0, score=0.832, total=   0.3s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    8.2s finished
# Best test ROC AUC:  0.8354363772402751
# Best params:  {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.5, 'gamma': 0.5, 'learning_rate': 0.03, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 15, 'missing': None, 'n_estimators': 50, 'n_jobs': -1, 'nthread': None, 'objective': 'binary:logistic', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': None, 'silent': None, 'subsample': 0.7, 'verbosity': 1}

# %%
clf_xgb = XGBClassifier(**best_params)

param_grid = {
    'reg_alpha': [0, 0.0001, 0.001, 0.1, 1],
    'reg_lambda': [0, 0.0001, 0.001, 0.1, 1]
}

best_params = find_params(clf_xgb, param_grid)
# Out:
# Fitting 1 folds for each of 25 candidates, totalling 25 fits
# [CV] reg_alpha=0, reg_lambda=0 .......................................
# [CV] ........... reg_alpha=0, reg_lambda=0, score=0.836, total=   0.2s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] reg_alpha=0, reg_lambda=0.0001 ..................................
# [CV] ...... reg_alpha=0, reg_lambda=0.0001, score=0.836, total=   0.2s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] reg_alpha=0, reg_lambda=0.001 ...................................
# [CV] ....... reg_alpha=0, reg_lambda=0.001, score=0.836, total=   0.2s
# [CV] reg_alpha=0, reg_lambda=0.1 .....................................
# [CV] ......... reg_alpha=0, reg_lambda=0.1, score=0.836, total=   0.2s
# [CV] reg_alpha=0, reg_lambda=1 .......................................
# [CV] ........... reg_alpha=0, reg_lambda=1, score=0.835, total=   0.2s
# [CV] reg_alpha=0.0001, reg_lambda=0 ..................................
# [CV] ...... reg_alpha=0.0001, reg_lambda=0, score=0.836, total=   0.2s
# [CV] reg_alpha=0.0001, reg_lambda=0.0001 .............................
# [CV] . reg_alpha=0.0001, reg_lambda=0.0001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.0001, reg_lambda=0.001 ..............................
# [CV] .. reg_alpha=0.0001, reg_lambda=0.001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.0001, reg_lambda=0.1 ................................
# [CV] .... reg_alpha=0.0001, reg_lambda=0.1, score=0.836, total=   0.2s
# [CV] reg_alpha=0.0001, reg_lambda=1 ..................................
# [CV] ...... reg_alpha=0.0001, reg_lambda=1, score=0.835, total=   0.2s
# [CV] reg_alpha=0.001, reg_lambda=0 ...................................
# [CV] ....... reg_alpha=0.001, reg_lambda=0, score=0.836, total=   0.2s
# [CV] reg_alpha=0.001, reg_lambda=0.0001 ..............................
# [CV] .. reg_alpha=0.001, reg_lambda=0.0001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.001, reg_lambda=0.001 ...............................
# [CV] ... reg_alpha=0.001, reg_lambda=0.001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.001, reg_lambda=0.1 .................................
# [CV] ..... reg_alpha=0.001, reg_lambda=0.1, score=0.836, total=   0.2s
# [CV] reg_alpha=0.001, reg_lambda=1 ...................................
# [CV] ....... reg_alpha=0.001, reg_lambda=1, score=0.835, total=   0.2s
# [CV] reg_alpha=0.1, reg_lambda=0 .....................................
# [CV] ......... reg_alpha=0.1, reg_lambda=0, score=0.836, total=   0.2s
# [CV] reg_alpha=0.1, reg_lambda=0.0001 ................................
# [CV] .... reg_alpha=0.1, reg_lambda=0.0001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.1, reg_lambda=0.001 .................................
# [CV] ..... reg_alpha=0.1, reg_lambda=0.001, score=0.836, total=   0.2s
# [CV] reg_alpha=0.1, reg_lambda=0.1 ...................................
# [CV] ....... reg_alpha=0.1, reg_lambda=0.1, score=0.836, total=   0.2s
# [CV] reg_alpha=0.1, reg_lambda=1 .....................................
# [CV] ......... reg_alpha=0.1, reg_lambda=1, score=0.836, total=   0.2s
# [CV] reg_alpha=1, reg_lambda=0 .......................................
# [CV] ........... reg_alpha=1, reg_lambda=0, score=0.835, total=   0.2s
# [CV] reg_alpha=1, reg_lambda=0.0001 ..................................
# [CV] ...... reg_alpha=1, reg_lambda=0.0001, score=0.835, total=   0.2s
# [CV] reg_alpha=1, reg_lambda=0.001 ...................................
# [CV] ....... reg_alpha=1, reg_lambda=0.001, score=0.835, total=   0.2s
# [CV] reg_alpha=1, reg_lambda=0.1 .....................................
# [CV] ......... reg_alpha=1, reg_lambda=0.1, score=0.835, total=   0.2s
# [CV] reg_alpha=1, reg_lambda=1 .......................................
# [CV] ........... reg_alpha=1, reg_lambda=1, score=0.835, total=   0.2s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    5.0s finished
# Best test ROC AUC:  0.835850692623438
# Best params:  {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.5, 'gamma': 0.5, 'learning_rate': 0.03, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 15, 'missing': None, 'n_estimators': 50, 'n_jobs': -1, 'nthread': None, 'objective': 'binary:logistic', 'random_state': 0, 'reg_alpha': 0.1, 'reg_lambda': 0.001, 'scale_pos_weight': 1, 'seed': None, 'silent': None, 'subsample': 0.7, 'verbosity': 1}

# %%
best_params['learning_rate'] = 0.01
best_params['n_estimators'] = 250

clf_xgb = XGBClassifier(**best_params)

clf_xgb.fit(X_train, y_train, eval_metric='auc', eval_set=[[X_train, y_train], [X_test, y_test]])
# Out:
# [0]	validation_0-auc:0.831046	validation_1-auc:0.808846
# [1]	validation_0-auc:0.854345	validation_1-auc:0.828971
# [2]	validation_0-auc:0.856293	validation_1-auc:0.82917
# [3]	validation_0-auc:0.85765	validation_1-auc:0.829623
# [4]	validation_0-auc:0.857849	validation_1-auc:0.831398
# [5]	validation_0-auc:0.859229	validation_1-auc:0.832637
# [6]	validation_0-auc:0.859908	validation_1-auc:0.832469
# [7]	validation_0-auc:0.861267	validation_1-auc:0.833691
# [8]	validation_0-auc:0.861657	validation_1-auc:0.834944
# [9]	validation_0-auc:0.862532	validation_1-auc:0.834753
# [10]	validation_0-auc:0.862551	validation_1-auc:0.833599
# [11]	validation_0-auc:0.862722	validation_1-auc:0.833641
# [12]	validation_0-auc:0.863489	validation_1-auc:0.834165
# [13]	validation_0-auc:0.86396	validation_1-auc:0.833741
# [14]	validation_0-auc:0.864538	validation_1-auc:0.83412
# [15]	validation_0-auc:0.864562	validation_1-auc:0.834492
# [16]	validation_0-auc:0.864939	validation_1-auc:0.833832
# [17]	validation_0-auc:0.864789	validation_1-auc:0.833518
# [18]	validation_0-auc:0.864955	validation_1-auc:0.833815
# [19]	validation_0-auc:0.865008	validation_1-auc:0.833662
# [20]	validation_0-auc:0.86491	validation_1-auc:0.833284
# [21]	validation_0-auc:0.864733	validation_1-auc:0.833317
# [22]	validation_0-auc:0.864806	validation_1-auc:0.833324
# [23]	validation_0-auc:0.864601	validation_1-auc:0.833283
# [24]	validation_0-auc:0.864887	validation_1-auc:0.833443
# [25]	validation_0-auc:0.865118	validation_1-auc:0.833233
# [26]	validation_0-auc:0.865059	validation_1-auc:0.833156
# [27]	validation_0-auc:0.865141	validation_1-auc:0.833192
# [28]	validation_0-auc:0.865047	validation_1-auc:0.833378
# [29]	validation_0-auc:0.865307	validation_1-auc:0.833562
# [30]	validation_0-auc:0.865747	validation_1-auc:0.833728
# [31]	validation_0-auc:0.865991	validation_1-auc:0.833643
# [32]	validation_0-auc:0.866145	validation_1-auc:0.833327
# [33]	validation_0-auc:0.866198	validation_1-auc:0.833074
# [34]	validation_0-auc:0.866058	validation_1-auc:0.833241
# [35]	validation_0-auc:0.866314	validation_1-auc:0.83311
# [36]	validation_0-auc:0.866302	validation_1-auc:0.8332
# [37]	validation_0-auc:0.866403	validation_1-auc:0.833512
# [38]	validation_0-auc:0.866629	validation_1-auc:0.833527
# [39]	validation_0-auc:0.866834	validation_1-auc:0.833394
# [40]	validation_0-auc:0.866847	validation_1-auc:0.833348
# [41]	validation_0-auc:0.867068	validation_1-auc:0.833264
# [42]	validation_0-auc:0.866801	validation_1-auc:0.833263
# [43]	validation_0-auc:0.866721	validation_1-auc:0.833485
# [44]	validation_0-auc:0.866871	validation_1-auc:0.833487
# [45]	validation_0-auc:0.866975	validation_1-auc:0.833577
# [46]	validation_0-auc:0.867034	validation_1-auc:0.833549
# [47]	validation_0-auc:0.867083	validation_1-auc:0.833374
# [48]	validation_0-auc:0.867211	validation_1-auc:0.833393
# [49]	validation_0-auc:0.867528	validation_1-auc:0.833429
# [50]	validation_0-auc:0.86748	validation_1-auc:0.83361
# [51]	validation_0-auc:0.867741	validation_1-auc:0.833729
# [52]	validation_0-auc:0.867774	validation_1-auc:0.833846
# [53]	validation_0-auc:0.867743	validation_1-auc:0.833616
# [54]	validation_0-auc:0.867703	validation_1-auc:0.83379
# [55]	validation_0-auc:0.867654	validation_1-auc:0.83379
# [56]	validation_0-auc:0.867787	validation_1-auc:0.833867
# [57]	validation_0-auc:0.867793	validation_1-auc:0.833761
# [58]	validation_0-auc:0.867747	validation_1-auc:0.833688
# [59]	validation_0-auc:0.867887	validation_1-auc:0.833904
# [60]	validation_0-auc:0.867827	validation_1-auc:0.833881
# [61]	validation_0-auc:0.867905	validation_1-auc:0.833974
# [62]	validation_0-auc:0.868009	validation_1-auc:0.833995
# [63]	validation_0-auc:0.868264	validation_1-auc:0.834081
# [64]	validation_0-auc:0.868304	validation_1-auc:0.8341
# [65]	validation_0-auc:0.868368	validation_1-auc:0.83421
# [66]	validation_0-auc:0.868463	validation_1-auc:0.834359
# [67]	validation_0-auc:0.868498	validation_1-auc:0.83411
# [68]	validation_0-auc:0.868495	validation_1-auc:0.834061
# [69]	validation_0-auc:0.868503	validation_1-auc:0.834205
# [70]	validation_0-auc:0.868498	validation_1-auc:0.834205
# [71]	validation_0-auc:0.868557	validation_1-auc:0.834051
# [72]	validation_0-auc:0.86852	validation_1-auc:0.834117
# [73]	validation_0-auc:0.868566	validation_1-auc:0.834138
# [74]	validation_0-auc:0.868562	validation_1-auc:0.834259
# [75]	validation_0-auc:0.868646	validation_1-auc:0.834301
# [76]	validation_0-auc:0.868689	validation_1-auc:0.834317
# [77]	validation_0-auc:0.868744	validation_1-auc:0.834308
# [78]	validation_0-auc:0.868745	validation_1-auc:0.83425
# [79]	validation_0-auc:0.868811	validation_1-auc:0.834437
# [80]	validation_0-auc:0.86902	validation_1-auc:0.834509
# [81]	validation_0-auc:0.869175	validation_1-auc:0.834617
# [82]	validation_0-auc:0.869364	validation_1-auc:0.83481
# [83]	validation_0-auc:0.869357	validation_1-auc:0.834831
# [84]	validation_0-auc:0.8694	validation_1-auc:0.834769
# [85]	validation_0-auc:0.869476	validation_1-auc:0.834701
# [86]	validation_0-auc:0.869552	validation_1-auc:0.834533
# [87]	validation_0-auc:0.869641	validation_1-auc:0.834458
# [88]	validation_0-auc:0.869641	validation_1-auc:0.834441
# [89]	validation_0-auc:0.869703	validation_1-auc:0.834612
# [90]	validation_0-auc:0.869774	validation_1-auc:0.834485
# [91]	validation_0-auc:0.869793	validation_1-auc:0.834488
# [92]	validation_0-auc:0.869871	validation_1-auc:0.834416
# [93]	validation_0-auc:0.869915	validation_1-auc:0.834427
# [94]	validation_0-auc:0.869907	validation_1-auc:0.834296
# [95]	validation_0-auc:0.869942	validation_1-auc:0.8342
# [96]	validation_0-auc:0.870072	validation_1-auc:0.834056
# [97]	validation_0-auc:0.870229	validation_1-auc:0.834035
# [98]	validation_0-auc:0.870338	validation_1-auc:0.834154
# [99]	validation_0-auc:0.870371	validation_1-auc:0.834137
# [100]	validation_0-auc:0.870516	validation_1-auc:0.834172
# [101]	validation_0-auc:0.870584	validation_1-auc:0.834293
# [102]	validation_0-auc:0.870703	validation_1-auc:0.834209
# [103]	validation_0-auc:0.870718	validation_1-auc:0.834242
# [104]	validation_0-auc:0.870834	validation_1-auc:0.834344
# [105]	validation_0-auc:0.870814	validation_1-auc:0.834325
# [106]	validation_0-auc:0.870841	validation_1-auc:0.834422
# [107]	validation_0-auc:0.870851	validation_1-auc:0.834375
# [108]	validation_0-auc:0.870838	validation_1-auc:0.834396
# [109]	validation_0-auc:0.870844	validation_1-auc:0.834363
# [110]	validation_0-auc:0.870871	validation_1-auc:0.834342
# [111]	validation_0-auc:0.870945	validation_1-auc:0.834417
# [112]	validation_0-auc:0.870951	validation_1-auc:0.83444
# [113]	validation_0-auc:0.871006	validation_1-auc:0.834314
# [114]	validation_0-auc:0.871023	validation_1-auc:0.834276
# [115]	validation_0-auc:0.871118	validation_1-auc:0.834279
# [116]	validation_0-auc:0.87125	validation_1-auc:0.834403
# [117]	validation_0-auc:0.871407	validation_1-auc:0.834381
# [118]	validation_0-auc:0.871441	validation_1-auc:0.834321
# [119]	validation_0-auc:0.871582	validation_1-auc:0.83437
# [120]	validation_0-auc:0.871663	validation_1-auc:0.834429
# [121]	validation_0-auc:0.871648	validation_1-auc:0.83436
# [122]	validation_0-auc:0.871648	validation_1-auc:0.834365
# [123]	validation_0-auc:0.871758	validation_1-auc:0.834478
# [124]	validation_0-auc:0.871768	validation_1-auc:0.834602
# [125]	validation_0-auc:0.87183	validation_1-auc:0.834604
# [126]	validation_0-auc:0.871785	validation_1-auc:0.83462
# [127]	validation_0-auc:0.871877	validation_1-auc:0.834644
# [128]	validation_0-auc:0.871939	validation_1-auc:0.83465
# [129]	validation_0-auc:0.871951	validation_1-auc:0.834713
# [130]	validation_0-auc:0.871961	validation_1-auc:0.834704
# [131]	validation_0-auc:0.871973	validation_1-auc:0.834599
# [132]	validation_0-auc:0.872004	validation_1-auc:0.834688
# [133]	validation_0-auc:0.872025	validation_1-auc:0.834683
# [134]	validation_0-auc:0.872057	validation_1-auc:0.834669
# [135]	validation_0-auc:0.872053	validation_1-auc:0.83459
# [136]	validation_0-auc:0.872005	validation_1-auc:0.834568
# [137]	validation_0-auc:0.871966	validation_1-auc:0.834602
# [138]	validation_0-auc:0.871977	validation_1-auc:0.834636
# [139]	validation_0-auc:0.872009	validation_1-auc:0.834692
# [140]	validation_0-auc:0.872149	validation_1-auc:0.834709
# [141]	validation_0-auc:0.872194	validation_1-auc:0.834718
# [142]	validation_0-auc:0.872214	validation_1-auc:0.83465
# [143]	validation_0-auc:0.87233	validation_1-auc:0.8347
# [144]	validation_0-auc:0.872376	validation_1-auc:0.834686
# [145]	validation_0-auc:0.87233	validation_1-auc:0.834693
# [146]	validation_0-auc:0.872341	validation_1-auc:0.834753
# [147]	validation_0-auc:0.872351	validation_1-auc:0.834726
# [148]	validation_0-auc:0.872336	validation_1-auc:0.834687
# [149]	validation_0-auc:0.872424	validation_1-auc:0.834703
# [150]	validation_0-auc:0.872448	validation_1-auc:0.83475
# [151]	validation_0-auc:0.872475	validation_1-auc:0.834764
# [152]	validation_0-auc:0.872623	validation_1-auc:0.83489
# [153]	validation_0-auc:0.872685	validation_1-auc:0.834855
# [154]	validation_0-auc:0.87268	validation_1-auc:0.834866
# [155]	validation_0-auc:0.872762	validation_1-auc:0.834915
# [156]	validation_0-auc:0.872782	validation_1-auc:0.834911
# [157]	validation_0-auc:0.872845	validation_1-auc:0.834934
# [158]	validation_0-auc:0.872868	validation_1-auc:0.834936
# [159]	validation_0-auc:0.872897	validation_1-auc:0.835019
# [160]	validation_0-auc:0.872899	validation_1-auc:0.835032
# [161]	validation_0-auc:0.873012	validation_1-auc:0.835121
# [162]	validation_0-auc:0.872989	validation_1-auc:0.835126
# [163]	validation_0-auc:0.873023	validation_1-auc:0.835158
# [164]	validation_0-auc:0.873096	validation_1-auc:0.835187
# [165]	validation_0-auc:0.873128	validation_1-auc:0.835292
# [166]	validation_0-auc:0.873168	validation_1-auc:0.835184
# [167]	validation_0-auc:0.873245	validation_1-auc:0.835119
# [168]	validation_0-auc:0.873267	validation_1-auc:0.835165
# [169]	validation_0-auc:0.873317	validation_1-auc:0.835212
# [170]	validation_0-auc:0.873345	validation_1-auc:0.835199
# [171]	validation_0-auc:0.873339	validation_1-auc:0.835243
# [172]	validation_0-auc:0.873461	validation_1-auc:0.835159
# [173]	validation_0-auc:0.873477	validation_1-auc:0.835182
# [174]	validation_0-auc:0.873523	validation_1-auc:0.835154
# [175]	validation_0-auc:0.873594	validation_1-auc:0.835196
# [176]	validation_0-auc:0.873557	validation_1-auc:0.835236
# [177]	validation_0-auc:0.873681	validation_1-auc:0.835282
# [178]	validation_0-auc:0.873725	validation_1-auc:0.835322
# [179]	validation_0-auc:0.873804	validation_1-auc:0.835404
# [180]	validation_0-auc:0.873861	validation_1-auc:0.835486
# [181]	validation_0-auc:0.873928	validation_1-auc:0.835418
# [182]	validation_0-auc:0.873986	validation_1-auc:0.835331
# [183]	validation_0-auc:0.874073	validation_1-auc:0.835352
# [184]	validation_0-auc:0.874113	validation_1-auc:0.835301
# [185]	validation_0-auc:0.874111	validation_1-auc:0.835346
# [186]	validation_0-auc:0.874146	validation_1-auc:0.835278
# [187]	validation_0-auc:0.874187	validation_1-auc:0.835339
# [188]	validation_0-auc:0.874179	validation_1-auc:0.835355
# [189]	validation_0-auc:0.874206	validation_1-auc:0.835411
# [190]	validation_0-auc:0.874276	validation_1-auc:0.83538
# [191]	validation_0-auc:0.874289	validation_1-auc:0.835418
# [192]	validation_0-auc:0.874287	validation_1-auc:0.835484
# [193]	validation_0-auc:0.874328	validation_1-auc:0.835577
# [194]	validation_0-auc:0.874341	validation_1-auc:0.835661
# [195]	validation_0-auc:0.874389	validation_1-auc:0.835712
# [196]	validation_0-auc:0.874405	validation_1-auc:0.835754
# [197]	validation_0-auc:0.874408	validation_1-auc:0.83568
# [198]	validation_0-auc:0.874458	validation_1-auc:0.835692
# [199]	validation_0-auc:0.874538	validation_1-auc:0.835638
# [200]	validation_0-auc:0.874534	validation_1-auc:0.835644
# [201]	validation_0-auc:0.874573	validation_1-auc:0.835761
# [202]	validation_0-auc:0.874603	validation_1-auc:0.835757
# [203]	validation_0-auc:0.874568	validation_1-auc:0.835743
# [204]	validation_0-auc:0.874583	validation_1-auc:0.835745
# [205]	validation_0-auc:0.874573	validation_1-auc:0.835748
# [206]	validation_0-auc:0.874574	validation_1-auc:0.835773
# [207]	validation_0-auc:0.874656	validation_1-auc:0.835736
# [208]	validation_0-auc:0.874649	validation_1-auc:0.835761
# [209]	validation_0-auc:0.874705	validation_1-auc:0.835776
# [210]	validation_0-auc:0.87472	validation_1-auc:0.835825
# [211]	validation_0-auc:0.874704	validation_1-auc:0.835803
# [212]	validation_0-auc:0.874751	validation_1-auc:0.835896
# [213]	validation_0-auc:0.874778	validation_1-auc:0.835872
# [214]	validation_0-auc:0.874789	validation_1-auc:0.835923
# [215]	validation_0-auc:0.874817	validation_1-auc:0.835909
# [216]	validation_0-auc:0.874872	validation_1-auc:0.835948
# [217]	validation_0-auc:0.874925	validation_1-auc:0.835951
# [218]	validation_0-auc:0.874978	validation_1-auc:0.835942
# [219]	validation_0-auc:0.875043	validation_1-auc:0.836051
# [220]	validation_0-auc:0.875039	validation_1-auc:0.83603
# [221]	validation_0-auc:0.87508	validation_1-auc:0.836
# [222]	validation_0-auc:0.875133	validation_1-auc:0.836023
# [223]	validation_0-auc:0.875182	validation_1-auc:0.836074
# [224]	validation_0-auc:0.875266	validation_1-auc:0.836042
# [225]	validation_0-auc:0.875312	validation_1-auc:0.836068
# [226]	validation_0-auc:0.875343	validation_1-auc:0.836053
# [227]	validation_0-auc:0.875399	validation_1-auc:0.836068
# [228]	validation_0-auc:0.875443	validation_1-auc:0.836058
# [229]	validation_0-auc:0.875478	validation_1-auc:0.836086
# [230]	validation_0-auc:0.875523	validation_1-auc:0.836074
# [231]	validation_0-auc:0.875547	validation_1-auc:0.836039
# [232]	validation_0-auc:0.875604	validation_1-auc:0.836082
# [233]	validation_0-auc:0.875598	validation_1-auc:0.836137
# [234]	validation_0-auc:0.875659	validation_1-auc:0.836095
# [235]	validation_0-auc:0.875696	validation_1-auc:0.836138
# [236]	validation_0-auc:0.875714	validation_1-auc:0.836124
# [237]	validation_0-auc:0.875805	validation_1-auc:0.8361
# [238]	validation_0-auc:0.875833	validation_1-auc:0.836105
# [239]	validation_0-auc:0.875863	validation_1-auc:0.836105
# [240]	validation_0-auc:0.875881	validation_1-auc:0.836166
# [241]	validation_0-auc:0.875947	validation_1-auc:0.836114
# [242]	validation_0-auc:0.876002	validation_1-auc:0.836084
# [243]	validation_0-auc:0.87604	validation_1-auc:0.836014
# [244]	validation_0-auc:0.876089	validation_1-auc:0.835967
# [245]	validation_0-auc:0.876165	validation_1-auc:0.836035
# [246]	validation_0-auc:0.876201	validation_1-auc:0.836037
# [247]	validation_0-auc:0.876229	validation_1-auc:0.836037
# [248]	validation_0-auc:0.876233	validation_1-auc:0.835984
# [249]	validation_0-auc:0.876267	validation_1-auc:0.836012
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0.5,
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=15, missing=None, n_estimators=250, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0.1, reg_lambda=0.001, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.7, verbosity=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
def save_online_metric(clf):
    return pd.DataFrame({'train': clf.evals_result()['validation_0']['auc'],
                         'test': clf.evals_result()['validation_1']['auc']})
res = save_online_metric(clf_xgb)
res.plot(title='ROC AUC')
plt.xlabel('iteration number')
plt.figure()
res.test.plot(title='ROC AUC TEST')
plt.xlabel('iteration number')
plt.show()

# %%
clf_xgb.fit(Xtrain, y, eval_metric='auc')
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5, gamma=0.5,
#               learning_rate=0.01, max_delta_step=0, max_depth=5,
#               min_child_weight=15, missing=None, n_estimators=250, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0.1, reg_lambda=0.001, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.7, verbosity=1)

# %%
predict = clf_xgb.predict_proba(Xtest)

# %%
result = pd.DataFrame(data=predict, index=test.index, columns=["noChurn", "Churn"])

# %%
result.index.name = 'Id'

# %%
result.Churn.to_csv('predictions.csv')
